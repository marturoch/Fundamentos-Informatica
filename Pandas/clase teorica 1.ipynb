# %%
#CLASE 1. INTRO A CIENCIA DE DATOS CON PANDAS

# %%
import pandas as pd 
import seaborn as sns 
import scipy.stats as ss

# %%
''' SERIES'''
una_serie = pd.Series(['Peru', 'Argentina', 'Bolivia', 'Uruguay', 'Brasil', 'Chile'], dtype='string')
una_serie
# Out:
# 0         Peru
# 1    Argentina
# 2      Bolivia
# 3      Uruguay
# 4       Brasil
# 5        Chile
# dtype: string

# %%
'''DATAFRAME'''
#será DataFrame(data=diccionario, index=filas, columns=columnas, dtype=tipos)
datos = {"Pais": ['Peru', 'Argentina', 'Bolivia', 'Uruguay', 'Brasil', 'Chile'], "Idioma oficial": ['Español', 'Español', 'Español', 'Español', 'Portugues', 'Español']}
paises_latam = pd.DataFrame(datos)
paises_latam
# Out:
#         Pais Idioma oficial
# 0       Peru        Español
# 1  Argentina        Español
# 2    Bolivia        Español
# 3    Uruguay        Español
# 4     Brasil      Portugues
# 5      Chile        Español

# %%
#🧗‍♀️ Desafío I: Estos métodos aceptan otros parámetros que merecen la pena ser explorados. Averiguá para qué sirven los parámetro sep, index_col, nrows y header
#🧗‍♀️ Desafío II: Descargá a tu computadora la tabla de personas que conforman el Ministerio de Ciencia y Tecnología de Argentina, en formato csv.
#Cargá (lee) la tabla a un DataFrame de Pandas ¿Qué forma te lectura de archivos usarías? ¿Qué separación entre columnas posee el archivo? ¿Cómo te diste cuenta? 🤔
#df = pd.read_csv(path_al_erchivo)
path = r'C:\Users\martu\Documents\martu\UCEMA\2 - PRIMER CUATRI\INFORMATICA\Base de Datos\personas_2011.csv'
personas = pd.read_csv(path, sep=";") #separado por comas
personas
#sep: delimitador a usar, indica como separar los elementos. Por defecto es la coma (comma-separated values). Pero en este caso usamos punto y coma porque los datos estan separados por comas
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0               1  2011        2    36                         -1
# 1               5  2011        1    48                          1
# 2               7  2011        2    30                          5
# 3              10  2011        2    51                          5
# 4              11  2011        1    39                          2
# ...           ...   ...      ...   ...                        ...
# 68547      185558  2011        2    -1                         -1
# 68548      185574  2011        2    55                         -1
# 68549      185583  2011        2    18                          7
# 68550      185590  2011        2    -1                          8
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                        -1                          -1
# ...

# %%
#HEADER:
pd.read_csv(path, sep=";", header=1)#usa los valores de la primera fila como nombre de columnas y ya no queda abajo de vuelta. La saca y ahora esta solo como enxabezado. Ahora la fila que era la segunda es la primera.
#Por defecto es 0
# Out:
#             1  2011  2  36  -1  -1.1  -1.2   64  4   0  ...  1.2  1.3   4488  \
# 0           5  2011  1  48   1   255   255  255  3   5  ...   13   17    118
# 1           7  2011  2  30   5   111   111  158  1  11  ...   13   13    587
# 2          10  2011  2  51   5   248   248   29  4   0  ...    3    4     44
# 3          11  2011  1  39   2   223   203  280  3   8  ...   15   18   7310
# 4          12  2011  2  48   1    58    57   55  1   1  ...    2    3    578
# ...       ...   ... ..  ..  ..   ...   ...  ... ..  ..  ...  ...  ...    ...
# 68546  185558  2011  2  -1  -1    -1    -1  263  2  -1  ...   -1   -1    221
# 68547  185574  2011  2  55  -1    -1    -1   38  2   0  ...    0    0  10971
# 68548  185583  2011  2  18   7    -1    -1  216  2  -1  ...   -1   -1  10624
# 68549  185590  2011  2  -1   8    -1    -1  250  2  -1  ...   -1   -1    396
# 68550  185608  2011  1  27   5   227   227  252  2  -1  ...   -1   -1   3765
#
# ...

# %%
pd.read_csv(path, sep=";", header=[1,2]) #usa las primeras dos filas como nombre de columnas
# Out:
#             1  2011  2  36 -1              64  4   0  ...   1       4488       \
#             5  2011  1  48  1  255 255.1  255  3   5  ...  13  17    118  B
# 0           7  2011  2  30  5  111   111  158  1  11  ...  13  13    587  D
# 1          10  2011  2  51  5  248   248   29  4   0  ...   3   4     44
# 2          11  2011  1  39  2  223   203  280  3   8  ...  15  18   7310  C
# 3          12  2011  2  48  1   58    57   55  1   1  ...   2   3    578  B
# 4          13  2011  2  41  5  192   192  281  4   0  ...   0   0    517
# ...       ...   ... ..  .. ..  ...   ...  ... ..  ..  ...  ..  ..    ...  ...
# 68545  185558  2011  2  -1 -1   -1    -1  263  2  -1  ...  -1  -1    221
# 68546  185574  2011  2  55 -1   -1    -1   38  2   0  ...   0   0  10971
# 68547  185583  2011  2  18  7   -1    -1  216  2  -1  ...  -1  -1  10624
# 68548  185590  2011  2  -1  8   -1    -1  250  2  -1  ...  -1  -1    396
# 68549  185608  2011  1  27  5  227   227  252  2  -1  ...  -1  -1   3765
# ...

# %%
#NROWS
pd.read_csv(path, sep=";", nrows=2) #devuelve las primeras 2 filas
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# 1                       255                 3                      5  ...
#
#    producciones_ult_3_anios  producciones_ult_4_anios  institucion_trabajo_id  \
# 0                         1                         1                    4488
# 1                        13                        17                     118
#
#    seniority_level categoria_conicet_id  categoria_incentivos  \
# ...

# %%
#INDEX_COL: columna(s) para usar como los labels del DataFrame> por defecto los labels son 0 1 2 3...
pd.read_csv(path, sep=";", index_col=2) #Usa la columa 2 como indice(acordarse que se arranca contando en el 0)
# Out:
#          persona_id  anio  edad  maximo_grado_academico_id  \
# sexo_id
# 2                 1  2011    36                         -1
# 1                 5  2011    48                          1
# 2                 7  2011    30                          5
# 2                10  2011    51                          5
# 1                11  2011    39                          2
# ...             ...   ...   ...                        ...
# 2            185558  2011    -1                         -1
# 2            185574  2011    55                         -1
# 2            185583  2011    18                          7
# 2            185590  2011    -1                          8
# 1            185608  2011    27                          5
#
#          disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# sexo_id
# 2                                          -1                          -1
# 1                                         255                         255
# ...

# %%
pd.read_csv(path, sep=";", index_col=[2,3]) #usa la fila 2 y 3 como indices
# Out:
#               persona_id  anio  maximo_grado_academico_id  \
# sexo_id edad
# 2        36            1  2011                         -1
# 1        48            5  2011                          1
# 2        30            7  2011                          5
#          51           10  2011                          5
# 1        39           11  2011                          2
# ...                  ...   ...                        ...
# 2       -1        185558  2011                         -1
#          55       185574  2011                         -1
#          18       185583  2011                          7
#         -1        185590  2011                          8
# 1        27       185608  2011                          5
#
#               disciplina_maximo_grado_academico_id  \
# sexo_id edad
# 2        36                                     -1
# 1        48                                    255
# 2        30                                    111
# ...

# %%
personas.head() #primeras 5 filas (default)
#Para pensar 🤔: ¿Cuántas filas se imprimen al hacer head? ¿Qué sucede si hacemos personas.head(10)? ¡Probalo!
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
df.head(10) #primeras 10 filas
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
# 5          12  2011        2    48                          1
# 6          13  2011        2    41                          5
# 7          15  2011        1    46                          1
# 8          17  2011        2    53                          2
# 9          19  2011        2    52                          1
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# ...

# %%
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68552 entries, 0 to 68551
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            68552 non-null  int64
#  1   anio                                  68552 non-null  int64
#  2   sexo_id                               68552 non-null  int64
#  3   edad                                  68552 non-null  int64
#  4   maximo_grado_academico_id             68552 non-null  int64
#  5   disciplina_maximo_grado_academico_id  68552 non-null  int64
#  6   disciplina_titulo_grado_id            68552 non-null  int64
#  7   disciplina_experticia_id              68552 non-null  int64
#  8   tipo_personal_id                      68552 non-null  int64
#  9   producciones_ult_anio                 68552 non-null  int64
#  10  producciones_ult_2_anios              68552 non-null  int64
# ...

# %%
personas.describe()
#Para pensar 🤔: ¿Qué tipo de información nos brinda el método describe? ¿Tienen sentido estos cálculos para todas las columnas?
#informacion estadistica para cada columna.Tiene sentido para las numericas.
# Out:
#           persona_id     anio       sexo_id          edad  \
# count   68552.000000  68552.0  68552.000000  68552.000000
# mean    52537.987280   2011.0      1.423430     38.475172
# std     40279.541919      0.0      0.494106     12.483655
# min         1.000000   2011.0      1.000000     -1.000000
# 25%     22112.500000   2011.0      1.000000     29.000000
# 50%     44284.500000   2011.0      1.000000     37.000000
# 75%     73350.250000   2011.0      2.000000     48.000000
# max    185608.000000   2011.0      2.000000     88.000000
#
#        maximo_grado_academico_id  disciplina_maximo_grado_academico_id  \
# count               68552.000000                          68552.000000
# mean                    3.306847                            152.966726
# std                     2.258145                            112.218458
# min                    -1.000000                             -1.000000
# 25%                     1.000000                             26.000000
# ...

# %%
personas['persona_id']
# Out:
# 0             1
# 1             5
# 2             7
# 3            10
# 4            11
#           ...
# 68547    185558
# 68548    185574
# 68549    185583
# 68550    185590
# 68551    185608
# Name: persona_id, Length: 68552, dtype: int64

# %%
personas['edad']
# Out:
# 0        36
# 1        48
# 2        30
# 3        51
# 4        39
#          ..
# 68547    -1
# 68548    55
# 68549    18
# 68550    -1
# 68551    27
# Name: edad, Length: 68552, dtype: int64

# %%
#Para pensar 🤔: ¿Podés imprimir la columna de los max_dedicacion_horaria_docente_id de nuestra tabla? ¿Cómo calcularías el promedio de esta columna?
personas['max_dedicacion_horaria_docente_id'] 
#o
personas.max_dedicacion_horaria_docente_id
# Out:
# 0        3.0
# 1        3.0
# 2        NaN
# 3        3.0
# 4        3.0
#         ...
# 68547    NaN
# 68548    NaN
# 68549    NaN
# 68550    NaN
# 68551    NaN
# Name: max_dedicacion_horaria_docente_id, Length: 68552, dtype: float64

# %%
personas.max_dedicacion_horaria_docente_id.mean()
# Out:
# 2.284580592105263

# %%
#Quizás nos resulte útil acceder, no a todos los datos de una columna, sino a un dato de una celda en particular. Para ello podemos utilizar iloc:
#personas.loc[fila, columna]
#esto devuelve el elemento que se encuentra en la fila con nombre fila y la columna de con nombre columna del DataFrame df. 
personas.loc[2, 'persona_id'] #se encuentra en la fila con nombre 2 y en la columna persona_id
# Out:
# 7

# %%
#Para pensar 🤔: ¿Qué resultado obtuviste? ¿Por qué? ¿Cómo obtendrías la edad de esa persona?
personas.loc[2,'edad']
# Out:
# 30

# %%
#Podemos acceder los datos de una columna del DataFrame como una lista mediante el método tolist():
#df['columna].tolist()
personas.edad.tolist()
# Out:
# [36,
#  48,
#  30,
#  51,
#  39,
#  48,
#  41,
#  46,
#  53,
#  52,
#  34,
#  33,
#  58,
#  53,
#  37,
#  60,
#  51,
#  49,
#  50,
#  47,
#  44,
#  47,
#  49,
#  36,
#  34,
#  54,
#  25,
#  34,
#  38,
#  67,
#  44,
#  51,
#  51,
#  38,
#  50,
#  30,
#  30,
#  41,
#  62,
#  40,
#  28,
#  34,
#  35,
#  43,
#  48,
#  62,
#  64,
#  64,
#  52,
#  36,
#  71,
#  43,
#  51,
#  45,
#  38,
#  44,
#  38,
#  65,
#  53,
#  68,
#  55,
#  59,
#  43,
#  24,
#  37,
#  53,
#  41,
#  44,
#  30,
#  43,
#  55,
#  34,
#  48,
#  30,
#  55,
#  34,
#  31,
#  41,
#  49,
#  42,
#  59,
#  33,
#  61,
#  56,
#  35,
#  35,
#  61,
#  53,
#  24,
#  52,
#  43,
#  33,
#  36,
#  54,
#  55,
#  50,
#  64,
#  58,
#  52,
#  32,
#  52,
#  51,
#  45,
#  21,
#  62,
#  52,
#  54,
#  71,
#  47,
#  48,
#  59,
#  45,
#  32,
#  54,
#  28,
#  50,
#  55,
#  27,
#  48,
#  58,
#  34,
#  57,
#  38,
#  38,
#  37,
#  55,
#  54,
#  38,
#  39,
#  54,
#  44,
#  41,
#  55,
#  27,
#  44,
#  40,
#  36,
#  35,
#  43,
#  40,
#  52,
#  45,
# ...

# %%
personas.edad.unique() #valores unicos
# Out:
# array([36, 48, 30, 51, 39, 41, 46, 53, 52, 34, 33, 58, 37, 60, 49, 50, 47,
#        44, 54, 25, 38, 67, 62, 40, 28, 35, 43, 64, 71, 45, 65, 68, 55, 59,
#        24, 31, 42, 61, 56, 32, 21, 27, 57, 72, 26, 70, 29, 66, 22, 78, 63,
#        69, 73, 23, 20, 74, 79, 80, 19, 76, 88, -1, 84, 75, 81, 83, 82, 77,
#        18, 85], dtype=int64)

# %%
#🧗‍♀️ Desafío IV: Extrae la columna seniority_level y contá cuántas personas tenían expertice nivel B, C y D
#🧗‍♀️ Desafío V: ¿Qué resultados obtuviste en cada caso? Explicá qué hace cada linea de código
personas['seniority_level'].count() #devuelve el total de valores de la columna que le pasamos, en este caso en seniority_level: 68552
# Out:
# 68552

# %%
personas.groupby('seniority_level').count() #cuenta para cada valor unico de la columna que le pasamos, la cantidad de veces por columna que aparece
# Out:
#                  persona_id   anio  sexo_id   edad  maximo_grado_academico_id  \
# seniority_level
#                       33085  33085    33085  33085                      33085
# A                      4834   4834     4834   4834                       4834
# B                      6674   6674     6674   6674                       6674
# C                     13645  13645    13645  13645                      13645
# D                      5774   5774     5774   5774                       5774
# S/D                    4540   4540     4540   4540                       4540
#
#                  disciplina_maximo_grado_academico_id  \
# seniority_level
#                                                 33085
# A                                                4834
# B                                                6674
# C                                               13645
# D                                                5774
# S/D                                              4540
#
# ...

# %%
personas.groupby('seniority_level').persona_id.count() #cuenta para cada valor de la columna que le pasamos, la cantidad de veces que aparece pero en este caso en la columna senirity_level
# Out:
# seniority_level
#        33085
# A       4834
# B       6674
# C      13645
# D       5774
# S/D     4540
# Name: persona_id, dtype: int64

# %%
#Podemos operar con las columnas con los mismo operadores relacionales y matemáticos que ya hemos visto:
#Para pensar 🤔: ¿Qué resultado nos daría en cada caso?
personas['edad'] * 2
# Out:
# 0         72
# 1         96
# 2         60
# 3        102
# 4         78
#         ...
# 68547     -2
# 68548    110
# 68549     36
# 68550     -2
# 68551     54
# Name: edad, Length: 68552, dtype: int64

# %%
personas['edad'] + 2
# Out:
# 0        38
# 1        50
# 2        32
# 3        53
# 4        41
#          ..
# 68547     1
# 68548    57
# 68549    20
# 68550     1
# 68551    29
# Name: edad, Length: 68552, dtype: int64

# %%
personas['edad'] > 2
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 68547    False
# 68548     True
# 68549     True
# 68550    False
# 68551     True
# Name: edad, Length: 68552, dtype: bool

# %%
#Pero los operadores tambien nos sirven también para filtrar nuestro DataFrame:
[personas['edad'] < 35 ]
# Out:
# [0        False
#  1        False
#  2         True
#  3        False
#  4        False
#           ...
#  68547     True
#  68548    False
#  68549     True
#  68550     True
#  68551     True
#  Name: edad, Length: 68552, dtype: bool]

# %%
menores35 = personas[personas['edad'] < 35 ] #deja solo las filas donde la edad es menor a 35
menores35
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 2               7  2011        2    30                          5
# 10             21  2011        1    34                          1
# 11             22  2011        2    33                          1
# 24             42  2011        2    34                          1
# 26             45  2011        2    25                          5
# ...           ...   ...      ...   ...                        ...
# 68546      185534  2011        2    -1                         -1
# 68547      185558  2011        2    -1                         -1
# 68549      185583  2011        2    18                          7
# 68550      185590  2011        2    -1                          8
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 2                                       111                         111
# ...

# %%
len(personas) - len(menores35) #39240 personas son mayores o iguales a 35
# Out:
# 39240

# %%
#🧗‍♀️ Desafío V: Contá cuántas personas de 30 años ingresaron al ministerio en 2011 ¿Cuántas formas de hacer este cálculo se te ocurren?
#forma 1:
mayor30 = personas[personas['edad']>30]
len(mayor30) #47925
#o:
len(personas[personas['edad']>30].edad.tolist())
# Out:
# 47925
